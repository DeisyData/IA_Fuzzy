# %% [markdown]
# <a href="https://colab.research.google.com/github/DeisyData/Curso-Inteligencia-Artificial/blob/main/Exploradora_errorCalibra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pylab import *
# importing required library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read a csv file
df = pd.read_csv('Calibra3.csv')

# %%
df.head() # apariencia visual del data frame
# Out:
#      Rango   Error
# 0  0-600mV  0.0200
# 1  0-600mV  0.0002
# 2    0-6 V  0.0000
# 3    0-6 V  0.0200
# 4    0-6 V  0.0002

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rango   69 non-null     object
#  1    Error  69 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.2+ KB

# %%
df.describe()
# Out:
#            Error
# count  69.000000
# mean    0.024896
# std     0.045854
# min     0.000000
# 25%     0.000080
# 50%     0.004000
# 75%     0.018000
# max     0.200000

# %%
sns.catplot(x='Rango', y=' Error', data=df, kind='point')
axhline(0.2, color='r', xmax=1)

# %%
# Diagrama de cajas muestra datos atipicos
sns.boxplot(x ='Rango', y =' Error', data = df,palette='Set3')
axhline(0.2, color='r', xmax=1)
# Out:
# <ipython-input-12-2691c17b292a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x ='Rango', y =' Error', data = df,palette='Set3')
